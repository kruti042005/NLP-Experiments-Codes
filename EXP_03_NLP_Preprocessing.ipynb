# %% [markdown]
# <a href="https://colab.research.google.com/github/kruti042005/NLP-Experiments-Codes/blob/main/EXP_03_NLP_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import re
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.util import ngrams
import spacy

# %%
# Download NLTK resources
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
# Load spaCy model
nlp = spacy.load('en_core_web_sm')
# Sample text
text = """Natural language processing is a subfield of artificial intelligence
that deals with the interaction between computers and humans using natural language."""

# %%
# Step 1: Data Cleaning
def clean_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text
cleaned_text = clean_text(text)
print("Cleaned Text:", cleaned_text)
# Out:
# Cleaned Text: natural language processing is a subfield of artificial intelligence that deals with the interaction between computers and humans using natural language

# %%
# Step 2: Tokenization
nltk_words = word_tokenize(cleaned_text)  # NLTK word tokenization
nltk_sentences = sent_tokenize(text)  # NLTK sentence tokenization
print("\nNLTK Word Tokens:", nltk_words)
print("\nNLTK Sentence Tokens:", nltk_sentences)
# SpaCy Tokenization
doc = nlp(cleaned_text)
spacy_tokens = [token.text for token in doc]
print("\nSpaCy Tokens:", spacy_tokens)
# Out:
# NLTK Word Tokens: ['natural', 'language', 'processing', 'is', 'a', 'subfield', 'of', 'artificial', 'intelligence', 'that', 'deals', 'with', 'the', 'interaction', 'between', 'computers', 'and', 'humans', 'using', 'natural', 'language']
#
# NLTK Sentence Tokens: ['Natural language processing is a subfield of artificial intelligence \nthat deals with the interaction between computers and humans using natural language.']
#
# SpaCy Tokens: ['natural', 'language', 'processing', 'is', 'a', 'subfield', 'of', 'artificial', 'intelligence', 'that', 'deals', 'with', 'the', 'interaction', 'between', 'computers', 'and', 'humans', 'using', 'natural', 'language']

# %%
# Step 3: Stemming (NLTK)
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in nltk_words]
print("\nStemmed Words (NLTK):", stemmed_words)
# Out:
# Stemmed Words (NLTK): ['natur', 'languag', 'process', 'is', 'a', 'subfield', 'of', 'artifici', 'intellig', 'that', 'deal', 'with', 'the', 'interact', 'between', 'comput', 'and', 'human', 'use', 'natur', 'languag']

# %%
# Step 4: Lemmatization (spaCy)
lemmatized_words = [token.lemma_ for token in doc]
print("\nLemmatized Words (spaCy):", lemmatized_words)
# Out:
# Lemmatized Words (spaCy): ['natural', 'language', 'processing', 'be', 'a', 'subfield', 'of', 'artificial', 'intelligence', 'that', 'deal', 'with', 'the', 'interaction', 'between', 'computer', 'and', 'human', 'use', 'natural', 'language']

# %%
# Step 5: Stop Words Removal
stop_words = set(stopwords.words('english'))
filtered_words_nltk = [word for word in nltk_words if word not in stop_words]
print("\nFiltered Words (NLTK):", filtered_words_nltk)
filtered_words_spacy = [token.text for token in doc if not token.is_stop]
print("\nFiltered Words (spaCy):", filtered_words_spacy)
# Out:
# Filtered Words (NLTK): ['natural', 'language', 'processing', 'subfield', 'artificial', 'intelligence', 'deals', 'interaction', 'computers', 'humans', 'using', 'natural', 'language']
#
# Filtered Words (spaCy): ['natural', 'language', 'processing', 'subfield', 'artificial', 'intelligence', 'deals', 'interaction', 'computers', 'humans', 'natural', 'language']

# %%
# Step 6: POS Tagging
nltk_pos_tags = nltk.pos_tag(nltk_words)
print("\nPOS Tags (NLTK):", nltk_pos_tags)
spacy_pos_tags = [(token.text, token.pos_) for token in doc]
print("\nPOS Tags (spaCy):", spacy_pos_tags)
# Out:
# POS Tags (NLTK): [('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('subfield', 'NN'), ('of', 'IN'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('that', 'IN'), ('deals', 'NNS'), ('with', 'IN'), ('the', 'DT'), ('interaction', 'NN'), ('between', 'IN'), ('computers', 'NNS'), ('and', 'CC'), ('humans', 'NNS'), ('using', 'VBG'), ('natural', 'JJ'), ('language', 'NN')]
#
# POS Tags (spaCy): [('natural', 'ADJ'), ('language', 'NOUN'), ('processing', 'NOUN'), ('is', 'AUX'), ('a', 'DET'), ('subfield', 'NOUN'), ('of', 'ADP'), ('artificial', 'ADJ'), ('intelligence', 'NOUN'), ('that', 'PRON'), ('deals', 'VERB'), ('with', 'ADP'), ('the', 'DET'), ('interaction', 'NOUN'), ('between', 'ADP'), ('computers', 'NOUN'), ('and', 'CCONJ'), ('humans', 'NOUN'), ('using', 'VERB'), ('natural', 'ADJ'), ('language', 'NOUN')]

# %%
# Step 7: N-Gram Modelling
# Trigram with NLTK
trigrams = list(ngrams(nltk_words, 3))
print("\nTrigrams (NLTK):", trigrams)
# Word Gram Modelling with NLTK
word_grams = list(ngrams(filtered_words_nltk, 2))  # Bigram example
print("\nWord Grams (NLTK):", word_grams)
# Out:
# Trigrams (NLTK): [('natural', 'language', 'processing'), ('language', 'processing', 'is'), ('processing', 'is', 'a'), ('is', 'a', 'subfield'), ('a', 'subfield', 'of'), ('subfield', 'of', 'artificial'), ('of', 'artificial', 'intelligence'), ('artificial', 'intelligence', 'that'), ('intelligence', 'that', 'deals'), ('that', 'deals', 'with'), ('deals', 'with', 'the'), ('with', 'the', 'interaction'), ('the', 'interaction', 'between'), ('interaction', 'between', 'computers'), ('between', 'computers', 'and'), ('computers', 'and', 'humans'), ('and', 'humans', 'using'), ('humans', 'using', 'natural'), ('using', 'natural', 'language')]
#
# Word Grams (NLTK): [('natural', 'language'), ('language', 'processing'), ('processing', 'subfield'), ('subfield', 'artificial'), ('artificial', 'intelligence'), ('intelligence', 'deals'), ('deals', 'interaction'), ('interaction', 'computers'), ('computers', 'humans'), ('humans', 'using'), ('using', 'natural'), ('natural', 'language')]
