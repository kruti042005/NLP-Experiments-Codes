# %% [markdown]
# <a href="https://colab.research.google.com/github/kruti042005/NLP-Experiments-Codes/blob/main/EXP_03_NLP_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import re

import nltk #Natural Language Toolkit.

from nltk.tokenize import word_tokenize, sent_tokenize
# word_tokenize → sentence ko individual words/tokens mein todta hai.
# sent_tokenize → paragraph ko individual sentences mein todta hai.

from nltk.corpus import stopwords
# stopwords common words ki list provide karta hai jo NLP mein often remove kiye jaate hain.

from nltk.stem import PorterStemmer
# PorterStemmer words ko unke root/stem form mein convert karta hai.

from nltk.util import ngrams
# ngrams ka use word combinations banane ke liye hota hai.

import spacy
# ➡️ spaCy ek powerful NLP library hai.

# Isse hum:

# tokenization
# POS tagging
# Named Entity Recognition (NER)
# dependency parsing
# lemmatization

# jaise tasks kar sakte hain.

# %%
# Download NLTK resources
nltk.download('punkt_tab')

# NLTK ka Punkt tokenizer data download karta hai.
# Ye mainly word_tokenize() aur sent_tokenize() jaise tokenization functions ke liye required data provide karta hai.

nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger') # ➡️ NLTK ka POS Tagger data download karta hai. | POS = Part of Speech
nltk.download('averaged_perceptron_tagger_eng') # ➡️ English language ke liye POS tagging model/data download karta hai.
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
# # Load spaCy model
# nlp = spacy.load('en_core_web_sm')
# # Sample text
# # text = "Artificial Intelligence is everywhere! In 2026, millions of people use AI every day. It is powerful, useful, and exciting!!!"

# from google.colab import drive

# drive.mount('/content/drive')
# file_path = "/content/drive/MyDrive/depth_of_model.txt"

# with open(file_path, "r") as file:
#     text = file.read()

# %% [markdown]
# # Web Scrapping

# %%
# !pip install requests beautifulsoup4

import requests
import re
from bs4 import BeautifulSoup

# Web Scraping
url = "https://quotes.toscrape.com/"
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

quotes = soup.find_all("span", class_="text")

# Convert all scraped quotes into one text
text = " ".join([quote.text for quote in quotes])

print("Original Text:")
print(text)
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.13/dist-packages (4.13.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests) (2026.7.22)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4) (4.16.0)
# Original Text:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.” “It is our choices, Harry, that show what we truly are, far more than our abilities.” “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.” “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.” “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.” “Try not to become a man of success. Rather become a man of value.” “It is better to be hated for what you are than to be loved for what you are not.” “I have not failed. I've just found 10,000 ways that won't work.” “A woman is like a tea bag; you never know how strong it is until it's in hot water.” “A day without sunshine is like, you know, night.”

# %%
# Step 1: Data Cleaning
def clean_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text
cleaned_text = clean_text(text)
print("Cleaned Text:", cleaned_text)
# Out:
# Cleaned Text: the world as we have created it is a process of our thinking it cannot be changed without changing our thinking it is our choices harry that show what we truly are far more than our abilities there are only two ways to live your life one is as though nothing is a miracle the other is as though everything is a miracle the person be it gentleman or lady who has not pleasure in a good novel must be intolerably stupid imperfection is beauty madness is genius and its better to be absolutely ridiculous than absolutely boring try not to become a man of success rather become a man of value it is better to be hated for what you are than to be loved for what you are not i have not failed ive just found ways that wont work a woman is like a tea bag you never know how strong it is until its in hot water a day without sunshine is like you know night

# %%
# Step 2: Tokenization
nltk_words = word_tokenize(cleaned_text)  # NLTK word tokenization
nltk_sentences = sent_tokenize(text)  # NLTK sentence tokenization
print("\nNLTK Word Tokens:", nltk_words)
print("\nNLTK Sentence Tokens:", nltk_sentences)
# SpaCy Tokenization
doc = nlp(cleaned_text)
spacy_tokens = [token.text for token in doc]
print("\nSpaCy Tokens:", spacy_tokens)
# Out:
# NLTK Word Tokens: ['the', 'world', 'as', 'we', 'have', 'created', 'it', 'is', 'a', 'process', 'of', 'our', 'thinking', 'it', 'can', 'not', 'be', 'changed', 'without', 'changing', 'our', 'thinking', 'it', 'is', 'our', 'choices', 'harry', 'that', 'show', 'what', 'we', 'truly', 'are', 'far', 'more', 'than', 'our', 'abilities', 'there', 'are', 'only', 'two', 'ways', 'to', 'live', 'your', 'life', 'one', 'is', 'as', 'though', 'nothing', 'is', 'a', 'miracle', 'the', 'other', 'is', 'as', 'though', 'everything', 'is', 'a', 'miracle', 'the', 'person', 'be', 'it', 'gentleman', 'or', 'lady', 'who', 'has', 'not', 'pleasure', 'in', 'a', 'good', 'novel', 'must', 'be', 'intolerably', 'stupid', 'imperfection', 'is', 'beauty', 'madness', 'is', 'genius', 'and', 'its', 'better', 'to', 'be', 'absolutely', 'ridiculous', 'than', 'absolutely', 'boring', 'try', 'not', 'to', 'become', 'a', 'man', 'of', 'success', 'rather', 'become', 'a', 'man', 'of', 'value', 'it', 'is', 'better', 'to', 'be', 'hated', 'for', 'what', 'you', 'are', 'than', 'to', 'be', 'loved', 'for', 'what', 'you', 'are', 'not', 'i', 'have', 'not', 'failed', 'ive', 'just', 'found', 'ways', 'that', 'wont', 'work', 'a', 'woman', 'is', 'like', 'a', 'tea', 'bag', 'you', 'never', 'know', 'how', 'strong', 'it', 'is', 'until', 'its', 'in', 'hot', 'water', 'a', 'day', 'without', 'sunshine', 'is', 'like', 'you', 'know', 'night']
#
# NLTK Sentence Tokens: ['“The world as we have created it is a process of our thinking.', 'It cannot be changed without changing our thinking.” “It is our choices, Harry, that show what we truly are, far more than our abilities.” “There are only two ways to live your life.', 'One is as though nothing is a miracle.', "The other is as though everything is a miracle.” “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.” “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.” “Try not to become a man of success.", 'Rather become a man of value.” “It is better to be hated for what you are than to be loved for what you are not.” “I have not failed.', "I've just found 10,000 ways that won't work.” “A woman is like a tea bag; you never know how strong it is until it's in hot water.” “A day without sunshine is like, you know, night.”"]
#
# SpaCy Tokens: ['the', 'world', 'as', 'we', 'have', 'created', 'it', 'is', 'a', 'process', 'of', 'our', 'thinking', 'it', 'can', 'not', 'be', 'changed', 'without', 'changing', 'our', 'thinking', 'it', 'is', 'our', 'choices', 'harry', 'that', 'show', 'what', 'we', 'truly', 'are', 'far', 'more', 'than', 'our', 'abilities', 'there', 'are', 'only', 'two', 'ways', 'to', 'live', 'your', 'life', 'one', 'is', 'as', 'though', 'nothing', 'is', 'a', 'miracle', 'the', 'other', 'is', 'as', 'though', 'everything', 'is', 'a', 'miracle', 'the', 'person', 'be', 'it', 'gentleman', 'or', 'lady', 'who', 'has', 'not', 'pleasure', 'in', 'a', 'good', 'novel', 'must', 'be', 'intolerably', 'stupid', 'imperfection', 'is', 'beauty', 'madness', 'is', 'genius', 'and', 'its', 'better', 'to', 'be', 'absolutely', 'ridiculous', 'than', 'absolutely', 'boring', 'try', 'not', 'to', 'become', 'a', 'man', 'of', 'success', 'rather', 'become', 'a', 'man', 'of', 'value', 'it', 'is', 'better', 'to', 'be', 'hated', 'for', 'what', 'you', 'are', 'than', 'to', 'be', 'loved', 'for', 'what', 'you', 'are', 'not', 'i', 'have', 'not', 'failed', 'i', 've', 'just', 'found', 'ways', 'that', 'wo', 'nt', 'work', 'a', 'woman', 'is', 'like', 'a', 'tea', 'bag', 'you', 'never', 'know', 'how', 'strong', 'it', 'is', 'until', 'its', 'in', 'hot', 'water', 'a', 'day', 'without', 'sunshine', 'is', 'like', 'you', 'know', 'night']

# %%
# Step 3: Stemming (NLTK)
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in nltk_words]
print("\nStemmed Words (NLTK):", stemmed_words)
# Out:
# Stemmed Words (NLTK): ['the', 'world', 'as', 'we', 'have', 'creat', 'it', 'is', 'a', 'process', 'of', 'our', 'think', 'it', 'can', 'not', 'be', 'chang', 'without', 'chang', 'our', 'think', 'it', 'is', 'our', 'choic', 'harri', 'that', 'show', 'what', 'we', 'truli', 'are', 'far', 'more', 'than', 'our', 'abil', 'there', 'are', 'onli', 'two', 'way', 'to', 'live', 'your', 'life', 'one', 'is', 'as', 'though', 'noth', 'is', 'a', 'miracl', 'the', 'other', 'is', 'as', 'though', 'everyth', 'is', 'a', 'miracl', 'the', 'person', 'be', 'it', 'gentleman', 'or', 'ladi', 'who', 'ha', 'not', 'pleasur', 'in', 'a', 'good', 'novel', 'must', 'be', 'intoler', 'stupid', 'imperfect', 'is', 'beauti', 'mad', 'is', 'geniu', 'and', 'it', 'better', 'to', 'be', 'absolut', 'ridicul', 'than', 'absolut', 'bore', 'tri', 'not', 'to', 'becom', 'a', 'man', 'of', 'success', 'rather', 'becom', 'a', 'man', 'of', 'valu', 'it', 'is', 'better', 'to', 'be', 'hate', 'for', 'what', 'you', 'are', 'than', 'to', 'be', 'love', 'for', 'what', 'you', 'are', 'not', 'i', 'have', 'not', 'fail', 'ive', 'just', 'found', 'way', 'that', 'wont', 'work', 'a', 'woman', 'is', 'like', 'a', 'tea', 'bag', 'you', 'never', 'know', 'how', 'strong', 'it', 'is', 'until', 'it', 'in', 'hot', 'water', 'a', 'day', 'without', 'sunshin', 'is', 'like', 'you', 'know', 'night']

# %%
# Step 4: Lemmatization (spaCy)
lemmatized_words = [token.lemma_ for token in doc]
print("\nLemmatized Words (spaCy):", lemmatized_words)
# Out:
# Lemmatized Words (spaCy): ['the', 'world', 'as', 'we', 'have', 'create', 'it', 'be', 'a', 'process', 'of', 'our', 'thinking', 'it', 'can', 'not', 'be', 'change', 'without', 'change', 'our', 'thinking', 'it', 'be', 'our', 'choice', 'harry', 'that', 'show', 'what', 'we', 'truly', 'be', 'far', 'more', 'than', 'our', 'ability', 'there', 'be', 'only', 'two', 'way', 'to', 'live', 'your', 'life', 'one', 'be', 'as', 'though', 'nothing', 'be', 'a', 'miracle', 'the', 'other', 'be', 'as', 'though', 'everything', 'be', 'a', 'miracle', 'the', 'person', 'be', 'it', 'gentleman', 'or', 'lady', 'who', 'have', 'not', 'pleasure', 'in', 'a', 'good', 'novel', 'must', 'be', 'intolerably', 'stupid', 'imperfection', 'be', 'beauty', 'madness', 'be', 'genius', 'and', 'its', 'well', 'to', 'be', 'absolutely', 'ridiculous', 'than', 'absolutely', 'boring', 'try', 'not', 'to', 'become', 'a', 'man', 'of', 'success', 'rather', 'become', 'a', 'man', 'of', 'value', 'it', 'be', 'well', 'to', 'be', 'hat', 'for', 'what', 'you', 'be', 'than', 'to', 'be', 'love', 'for', 'what', 'you', 'be', 'not', 'I', 'have', 'not', 'fail', 'I', 've', 'just', 'find', 'way', 'that', 'will', 'not', 'work', 'a', 'woman', 'be', 'like', 'a', 'tea', 'bag', 'you', 'never', 'know', 'how', 'strong', 'it', 'be', 'until', 'its', 'in', 'hot', 'water', 'a', 'day', 'without', 'sunshine', 'be', 'like', 'you', 'know', 'night']

# %%
# Step 5: Stop Words Removal
stop_words = set(stopwords.words('english'))
filtered_words_nltk = [word for word in nltk_words if word not in stop_words]
print("\nFiltered Words (NLTK):", filtered_words_nltk)
filtered_words_spacy = [token.text for token in doc if not token.is_stop]
print("\nFiltered Words (spaCy):", filtered_words_spacy)
# Out:
# Filtered Words (NLTK): ['world', 'created', 'process', 'thinking', 'changed', 'without', 'changing', 'thinking', 'choices', 'harry', 'show', 'truly', 'far', 'abilities', 'two', 'ways', 'live', 'life', 'one', 'though', 'nothing', 'miracle', 'though', 'everything', 'miracle', 'person', 'gentleman', 'lady', 'pleasure', 'good', 'novel', 'must', 'intolerably', 'stupid', 'imperfection', 'beauty', 'madness', 'genius', 'better', 'absolutely', 'ridiculous', 'absolutely', 'boring', 'try', 'become', 'man', 'success', 'rather', 'become', 'man', 'value', 'better', 'hated', 'loved', 'failed', 'ive', 'found', 'ways', 'wont', 'work', 'woman', 'like', 'tea', 'bag', 'never', 'know', 'strong', 'hot', 'water', 'day', 'without', 'sunshine', 'like', 'know', 'night']
#
# Filtered Words (spaCy): ['world', 'created', 'process', 'thinking', 'changed', 'changing', 'thinking', 'choices', 'harry', 'truly', 'far', 'abilities', 'ways', 'live', 'life', 'miracle', 'miracle', 'person', 'gentleman', 'lady', 'pleasure', 'good', 'novel', 'intolerably', 'stupid', 'imperfection', 'beauty', 'madness', 'genius', 'better', 'absolutely', 'ridiculous', 'absolutely', 'boring', 'try', 'man', 'success', 'man', 'value', 'better', 'hated', 'loved', 'failed', 've', 'found', 'ways', 'wo', 'nt', 'work', 'woman', 'like', 'tea', 'bag', 'know', 'strong', 'hot', 'water', 'day', 'sunshine', 'like', 'know', 'night']

# %%
# Step 6: POS Tagging
nltk_pos_tags = nltk.pos_tag(nltk_words)
print("\nPOS Tags (NLTK):", nltk_pos_tags)
spacy_pos_tags = [(token.text, token.pos_) for token in doc]
print("\nPOS Tags (spaCy):", spacy_pos_tags)
# Out:
# POS Tags (NLTK): [('the', 'DT'), ('world', 'NN'), ('as', 'IN'), ('we', 'PRP'), ('have', 'VBP'), ('created', 'VBN'), ('it', 'PRP'), ('is', 'VBZ'), ('a', 'DT'), ('process', 'NN'), ('of', 'IN'), ('our', 'PRP$'), ('thinking', 'VBG'), ('it', 'PRP'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('changed', 'VBN'), ('without', 'IN'), ('changing', 'VBG'), ('our', 'PRP$'), ('thinking', 'VBG'), ('it', 'PRP'), ('is', 'VBZ'), ('our', 'PRP$'), ('choices', 'NNS'), ('harry', 'VBP'), ('that', 'IN'), ('show', 'VBP'), ('what', 'WP'), ('we', 'PRP'), ('truly', 'VBP'), ('are', 'VBP'), ('far', 'RB'), ('more', 'JJR'), ('than', 'IN'), ('our', 'PRP$'), ('abilities', 'NNS'), ('there', 'EX'), ('are', 'VBP'), ('only', 'RB'), ('two', 'CD'), ('ways', 'NNS'), ('to', 'TO'), ('live', 'VB'), ('your', 'PRP$'), ('life', 'NN'), ('one', 'CD'), ('is', 'VBZ'), ('as', 'IN'), ('though', 'IN'), ('nothing', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('miracle', 'NN'), ('the', 'DT'), ('other', 'JJ'), ('is', 'VBZ'), ('as', 'IN'), ('though', 'IN'), ('everything', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('miracle', 'NN'), ('the', 'DT'), ('person', 'NN'), ('be', 'VB'), ('it', 'PRP'), ('gentleman', 'JJ'), ('or', 'CC'), ('lady', 'NN'), ('who', 'WP'), ('has', 'VBZ'), ('not', 'RB'), ('pleasure', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('good', 'JJ'), ('novel', 'NN'), ('must', 'MD'), ('be', 'VB'), ('intolerably', 'RB'), ('stupid', 'JJ'), ('imperfection', 'NN'), ('is', 'VBZ'), ('beauty', 'JJ'), ('madness', 'NN'), ('is', 'VBZ'), ('genius', 'JJ'), ('and', 'CC'), ('its', 'PRP$'), ('better', 'JJR'), ('to', 'TO'), ('be', 'VB'), ('absolutely', 'RB'), ('ridiculous', 'JJ'), ('than', 'IN'), ('absolutely', 'RB'), ('boring', 'VBG'), ('try', 'PRP'), ('not', 'RB'), ('to', 'TO'), ('become', 'VB'), ('a', 'DT'), ('man', 'NN'), ('of', 'IN'), ('success', 'NN'), ('rather', 'RB'), ('become', 'VBD'), ('a', 'DT'), ('man', 'NN'), ('of', 'IN'), ('value', 'NN'), ('it', 'PRP'), ('is', 'VBZ'), ('better', 'RBR'), ('to', 'TO'), ('be', 'VB'), ('hated', 'VBN'), ('for', 'IN'), ('what', 'WP'), ('you', 'PRP'), ('are', 'VBP'), ('than', 'IN'), ('to', 'TO'), ('be', 'VB'), ('loved', 'VBN'), ('for', 'IN'), ('what', 'WP'), ('you', 'PRP'), ('are', 'VBP'), ('not', 'RB'), ('i', 'RB'), ('have', 'VBP'), ('not', 'RB'), ('failed', 'VBN'), ('ive', 'JJ'), ('just', 'RB'), ('found', 'VBN'), ('ways', 'NNS'), ('that', 'WDT'), ('wont', 'VBP'), ('work', 'VB'), ('a', 'DT'), ('woman', 'NN'), ('is', 'VBZ'), ('like', 'IN'), ('a', 'DT'), ('tea', 'NN'), ('bag', 'NN'), ('you', 'PRP'), ('never', 'RB'), ('know', 'VBP'), ('how', 'WRB'), ('strong', 'JJ'), ('it', 'PRP'), ('is', 'VBZ'), ('until', 'IN'), ('its', 'PRP$'), ('in', 'IN'), ('hot', 'JJ'), ('water', 'NN'), ('a', 'DT'), ('day', 'NN'), ('without', 'IN'), ('sunshine', 'NN'), ('is', 'VBZ'), ('like', 'IN'), ('you', 'PRP'), ('know', 'VBP'), ('night', 'NN')]
#
# POS Tags (spaCy): [('the', 'DET'), ('world', 'NOUN'), ('as', 'SCONJ'), ('we', 'PRON'), ('have', 'AUX'), ('created', 'VERB'), ('it', 'PRON'), ('is', 'AUX'), ('a', 'DET'), ('process', 'NOUN'), ('of', 'ADP'), ('our', 'PRON'), ('thinking', 'NOUN'), ('it', 'PRON'), ('can', 'AUX'), ('not', 'PART'), ('be', 'AUX'), ('changed', 'VERB'), ('without', 'ADP'), ('changing', 'VERB'), ('our', 'PRON'), ('thinking', 'NOUN'), ('it', 'PRON'), ('is', 'AUX'), ('our', 'PRON'), ('choices', 'NOUN'), ('harry', 'VERB'), ('that', 'PRON'), ('show', 'VERB'), ('what', 'PRON'), ('we', 'PRON'), ('truly', 'ADV'), ('are', 'AUX'), ('far', 'ADV'), ('more', 'ADJ'), ('than', 'ADP'), ('our', 'PRON'), ('abilities', 'NOUN'), ('there', 'PRON'), ('are', 'VERB'), ('only', 'ADV'), ('two', 'NUM'), ('ways', 'NOUN'), ('to', 'PART'), ('live', 'VERB'), ('your', 'PRON'), ('life', 'NOUN'), ('one', 'NUM'), ('is', 'AUX'), ('as', 'SCONJ'), ('though', 'SCONJ'), ('nothing', 'PRON'), ('is', 'AUX'), ('a', 'DET'), ('miracle', 'NOUN'), ('the', 'DET'), ('other', 'ADJ'), ('is', 'AUX'), ('as', 'SCONJ'), ('though', 'SCONJ'), ('everything', 'PRON'), ('is', 'AUX'), ('a', 'DET'), ('miracle', 'NOUN'), ('the', 'DET'), ('person', 'NOUN'), ('be', 'AUX'), ('it', 'PRON'), ('gentleman', 'NOUN'), ('or', 'CCONJ'), ('lady', 'NOUN'), ('who', 'PRON'), ('has', 'AUX'), ('not', 'PART'), ('pleasure', 'VERB'), ('in', 'ADP'), ('a', 'DET'), ('good', 'ADJ'), ('novel', 'NOUN'), ('must', 'AUX'), ('be', 'AUX'), ('intolerably', 'ADV'), ('stupid', 'ADJ'), ('imperfection', 'NOUN'), ('is', 'AUX'), ('beauty', 'NOUN'), ('madness', 'NOUN'), ('is', 'AUX'), ('genius', 'NOUN'), ('and', 'CCONJ'), ('its', 'PRON'), ('better', 'ADJ'), ('to', 'PART'), ('be', 'AUX'), ('absolutely', 'ADV'), ('ridiculous', 'ADJ'), ('than', 'ADP'), ('absolutely', 'ADV'), ('boring', 'ADJ'), ('try', 'VERB'), ('not', 'PART'), ('to', 'PART'), ('become', 'VERB'), ('a', 'DET'), ('man', 'NOUN'), ('of', 'ADP'), ('success', 'NOUN'), ('rather', 'ADV'), ('become', 'VERB'), ('a', 'DET'), ('man', 'NOUN'), ('of', 'ADP'), ('value', 'NOUN'), ('it', 'PRON'), ('is', 'AUX'), ('better', 'ADJ'), ('to', 'PART'), ('be', 'AUX'), ('hated', 'VERB'), ('for', 'ADP'), ('what', 'PRON'), ('you', 'PRON'), ('are', 'AUX'), ('than', 'ADP'), ('to', 'PART'), ('be', 'AUX'), ('loved', 'VERB'), ('for', 'ADP'), ('what', 'PRON'), ('you', 'PRON'), ('are', 'AUX'), ('not', 'PART'), ('i', 'PRON'), ('have', 'AUX'), ('not', 'PART'), ('failed', 'VERB'), ('i', 'PRON'), ('ve', 'AUX'), ('just', 'ADV'), ('found', 'VERB'), ('ways', 'NOUN'), ('that', 'PRON'), ('wo', 'AUX'), ('nt', 'PART'), ('work', 'VERB'), ('a', 'DET'), ('woman', 'NOUN'), ('is', 'AUX'), ('like', 'ADP'), ('a', 'DET'), ('tea', 'NOUN'), ('bag', 'NOUN'), ('you', 'PRON'), ('never', 'ADV'), ('know', 'VERB'), ('how', 'SCONJ'), ('strong', 'ADJ'), ('it', 'PRON'), ('is', 'AUX'), ('until', 'SCONJ'), ('its', 'PRON'), ('in', 'ADP'), ('hot', 'ADJ'), ('water', 'NOUN'), ('a', 'DET'), ('day', 'NOUN'), ('without', 'ADP'), ('sunshine', 'NOUN'), ('is', 'AUX'), ('like', 'INTJ'), ('you', 'PRON'), ('know', 'VERB'), ('night', 'NOUN')]

# %%
# Step 7: N-Gram Modelling
# Trigram with NLTK
trigrams = list(ngrams(nltk_words, 3))
print("\nTrigrams (NLTK):", trigrams)
# Word Gram Modelling with NLTK
word_grams = list(ngrams(filtered_words_nltk, 2))  # Bigram example
print("\nWord Grams (NLTK):", word_grams)
# Out:
# Trigrams (NLTK): [('the', 'world', 'as'), ('world', 'as', 'we'), ('as', 'we', 'have'), ('we', 'have', 'created'), ('have', 'created', 'it'), ('created', 'it', 'is'), ('it', 'is', 'a'), ('is', 'a', 'process'), ('a', 'process', 'of'), ('process', 'of', 'our'), ('of', 'our', 'thinking'), ('our', 'thinking', 'it'), ('thinking', 'it', 'can'), ('it', 'can', 'not'), ('can', 'not', 'be'), ('not', 'be', 'changed'), ('be', 'changed', 'without'), ('changed', 'without', 'changing'), ('without', 'changing', 'our'), ('changing', 'our', 'thinking'), ('our', 'thinking', 'it'), ('thinking', 'it', 'is'), ('it', 'is', 'our'), ('is', 'our', 'choices'), ('our', 'choices', 'harry'), ('choices', 'harry', 'that'), ('harry', 'that', 'show'), ('that', 'show', 'what'), ('show', 'what', 'we'), ('what', 'we', 'truly'), ('we', 'truly', 'are'), ('truly', 'are', 'far'), ('are', 'far', 'more'), ('far', 'more', 'than'), ('more', 'than', 'our'), ('than', 'our', 'abilities'), ('our', 'abilities', 'there'), ('abilities', 'there', 'are'), ('there', 'are', 'only'), ('are', 'only', 'two'), ('only', 'two', 'ways'), ('two', 'ways', 'to'), ('ways', 'to', 'live'), ('to', 'live', 'your'), ('live', 'your', 'life'), ('your', 'life', 'one'), ('life', 'one', 'is'), ('one', 'is', 'as'), ('is', 'as', 'though'), ('as', 'though', 'nothing'), ('though', 'nothing', 'is'), ('nothing', 'is', 'a'), ('is', 'a', 'miracle'), ('a', 'miracle', 'the'), ('miracle', 'the', 'other'), ('the', 'other', 'is'), ('other', 'is', 'as'), ('is', 'as', 'though'), ('as', 'though', 'everything'), ('though', 'everything', 'is'), ('everything', 'is', 'a'), ('is', 'a', 'miracle'), ('a', 'miracle', 'the'), ('miracle', 'the', 'person'), ('the', 'person', 'be'), ('person', 'be', 'it'), ('be', 'it', 'gentleman'), ('it', 'gentleman', 'or'), ('gentleman', 'or', 'lady'), ('or', 'lady', 'who'), ('lady', 'who', 'has'), ('who', 'has', 'not'), ('has', 'not', 'pleasure'), ('not', 'pleasure', 'in'), ('pleasure', 'in', 'a'), ('in', 'a', 'good'), ('a', 'good', 'novel'), ('good', 'novel', 'must'), ('novel', 'must', 'be'), ('must', 'be', 'intolerably'), ('be', 'intolerably', 'stupid'), ('intolerably', 'stupid', 'imperfection'), ('stupid', 'imperfection', 'is'), ('imperfection', 'is', 'beauty'), ('is', 'beauty', 'madness'), ('beauty', 'madness', 'is'), ('madness', 'is', 'genius'), ('is', 'genius', 'and'), ('genius', 'and', 'its'), ('and', 'its', 'better'), ('its', 'better', 'to'), ('better', 'to', 'be'), ('to', 'be', 'absolutely'), ('be', 'absolutely', 'ridiculous'), ('absolutely', 'ridiculous', 'than'), ('ridiculous', 'than', 'absolutely'), ('than', 'absolutely', 'boring'), ('absolutely', 'boring', 'try'), ('boring', 'try', 'not'), ('try', 'not', 'to'), ('not', 'to', 'become'), ('to', 'become', 'a'), ('become', 'a', 'man'), ('a', 'man', 'of'), ('man', 'of', 'success'), ('of', 'success', 'rather'), ('success', 'rather', 'become'), ('rather', 'become', 'a'), ('become', 'a', 'man'), ('a', 'man', 'of'), ('man', 'of', 'value'), ('of', 'value', 'it'), ('value', 'it', 'is'), ('it', 'is', 'better'), ('is', 'better', 'to'), ('better', 'to', 'be'), ('to', 'be', 'hated'), ('be', 'hated', 'for'), ('hated', 'for', 'what'), ('for', 'what', 'you'), ('what', 'you', 'are'), ('you', 'are', 'than'), ('are', 'than', 'to'), ('than', 'to', 'be'), ('to', 'be', 'loved'), ('be', 'loved', 'for'), ('loved', 'for', 'what'), ('for', 'what', 'you'), ('what', 'you', 'are'), ('you', 'are', 'not'), ('are', 'not', 'i'), ('not', 'i', 'have'), ('i', 'have', 'not'), ('have', 'not', 'failed'), ('not', 'failed', 'ive'), ('failed', 'ive', 'just'), ('ive', 'just', 'found'), ('just', 'found', 'ways'), ('found', 'ways', 'that'), ('ways', 'that', 'wont'), ('that', 'wont', 'work'), ('wont', 'work', 'a'), ('work', 'a', 'woman'), ('a', 'woman', 'is'), ('woman', 'is', 'like'), ('is', 'like', 'a'), ('like', 'a', 'tea'), ('a', 'tea', 'bag'), ('tea', 'bag', 'you'), ('bag', 'you', 'never'), ('you', 'never', 'know'), ('never', 'know', 'how'), ('know', 'how', 'strong'), ('how' ...
#
# Word Grams (NLTK): [('world', 'created'), ('created', 'process'), ('process', 'thinking'), ('thinking', 'changed'), ('changed', 'without'), ('without', 'changing'), ('changing', 'thinking'), ('thinking', 'choices'), ('choices', 'harry'), ('harry', 'show'), ('show', 'truly'), ('truly', 'far'), ('far', 'abilities'), ('abilities', 'two'), ('two', 'ways'), ('ways', 'live'), ('live', 'life'), ('life', 'one'), ('one', 'though'), ('though', 'nothing'), ('nothing', 'miracle'), ('miracle', 'though'), ('though', 'everything'), ('everything', 'miracle'), ('miracle', 'person'), ('person', 'gentleman'), ('gentleman', 'lady'), ('lady', 'pleasure'), ('pleasure', 'good'), ('good', 'novel'), ('novel', 'must'), ('must', 'intolerably'), ('intolerably', 'stupid'), ('stupid', 'imperfection'), ('imperfection', 'beauty'), ('beauty', 'madness'), ('madness', 'genius'), ('genius', 'better'), ('better', 'absolutely'), ('absolutely', 'ridiculous'), ('ridiculous', 'absolutely'), ('absolutely', 'boring'), ('boring', 'try'), ('try', 'become'), ('become', 'man'), ('man', 'success'), ('success', 'rather'), ('rather', 'become'), ('become', 'man'), ('man', 'value'), ('value', 'better'), ('better', 'hated'), ('hated', 'loved'), ('loved', 'failed'), ('failed', 'ive'), ('ive', 'found'), ('found', 'ways'), ('ways', 'wont'), ('wont', 'work'), ('work', 'woman'), ('woman', 'like'), ('like', 'tea'), ('tea', 'bag'), ('bag', 'never'), ('never', 'know'), ('know', 'strong'), ('strong', 'hot'), ('hot', 'water'), ('water', 'day'), ('day', 'without'), ('without', 'sunshine'), ('sunshine', 'like'), ('like', 'know'), ('know', 'night')]
